# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/aarya/NSV/Data/NoSchoolViolenceLabels.csv')

# %%
df.head()
# Out:
#        Behavior Name/Term                                         Definition  \
# 0    "Chinese Fire Drill"  a prank in which the passengers of a motor veh...
# 1           Abusive Cycle  This is the name for the ongoing rotation betw...
# 2  Action Assembly Theory  a group of theories that seek to explain verba...
# 3                  Active                         always busy with something
# 4                adoption                                                NaN
#
#   Definition 2  Weapons  Bullying  Physical  Dating
# 0          NaN      NaN       0.0       0.0     NaN
# 1          NaN      1.0       0.0       NaN     NaN
# 2          NaN      NaN       0.0       0.0     NaN
# 3          NaN      NaN       0.0       1.0     NaN
# 4          NaN      1.0       0.0       0.0     NaN

# %%
df = df.drop(['Definition', 'Definition 2'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-31d73eee72b4> in <module>()
# ----> 1 df = df.drop(['Definition', 'Definition 2'], axis=1)
#       2 df
#
# /Users/aarya/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1906             else:
# -> 1907                 new_axis = axis.drop(labels, errors=errors)
#    1908             dropped = self.reindex(**{axis_name: new_axis})
#    1909             try:
#
# /Users/aarya/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3260             if errors != 'ignore':
#    3261                 raise ValueError('labels %s not contained in axis' %
# -> 3262                                  labels[mask])
# ...

# %%
df.fillna(0)
# Out:
#                            Behavior Name/Term  Weapons  Bullying  Physical  \
# 0                        "Chinese Fire Drill"      0.0       0.0       0.0
# 1                               Abusive Cycle      1.0       0.0       0.0
# 2                      Action Assembly Theory      0.0       0.0       0.0
# 3                                      Active      0.0       0.0       1.0
# 4                                    adoption      1.0       0.0       0.0
# 5                                   Age 17-19      1.0       0.0       0.0
# 6                   aggresion towards objects      1.0       0.0       1.0
# 7                                  Aggressive      1.0       1.0       1.0
# 8                                 alcohol use      1.0       1.0       1.0
# 9                                  Alienation      1.0       1.0       0.0
# 10                     Alloplastic adaptation      0.0       0.0       0.0
# ...

# %%
df.to_csv('NSV-Behavior-Label', encoding='utf-8', index=False)
